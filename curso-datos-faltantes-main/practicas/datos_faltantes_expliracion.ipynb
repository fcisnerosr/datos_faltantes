# %%
import pandas as pd
from pathlib import Path

# %%
NB_DIR = Path().cwd()
print(f'NB_DIR: {NB_DIR}')
# Out:
# NB_DIR: /home/paco/datos_faltantes/curso-datos-faltantes-main/practicas

# %%
SRC_DIR = (NB_DIR/'..'/'jupyter')
print(f'SRC_DIR: {SRC_DIR}')
# %ls
# Out:
# SRC_DIR: /home/paco/datos_faltantes/curso-datos-faltantes-main/practicas/../jupyter
# datos_faltantes_expliracion.ipynb  test.csv     train.csv
# gender_submission.csv              titanic.zip

# %%
df_gender = pd.read_csv('gender_submission.csv')
df_test = pd.read_csv('test.csv')
df_train = pd.read_csv('train.csv')

# %%
df_gender.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         1
# 2          894         0
# 3          895         0
# 4          896         1
